# %%
import requests

url = "https://api.apilayer.com/exchangerates_data/symbols"

payload = {}
headers= {
  "apikey": "5Zg6VsEVrBDjAdiYupAhUb6sMyaFMytz"
}

response = requests.request("GET", url, headers=headers, data = payload)

status_code = response.status_code
result = response.json()

# %%
result
# Out:
# {'message': 'You cannot consume this service'}

# %%
import requests

url = f"https://api.apilayer.com/exchangerates_data/latest?symbols={curr}&base=NGN"

payload = {}
headers= {
  "apikey": "5Zg6VsEVrBDjAdiYupAhUb6sMyaFMytz"
}

response = requests.request("GET", url, headers=headers, data = payload)

status_code = response.status_code
result = response.json()

# %%
len(result["rates"])
# Out:
# 154

# %%
result
# Out:
# {'success': True,
#  'timestamp': 1665659403,
#  'base': 'NGN',
#  'date': '2022-10-13',
#  'rates': {'AFN': 0.196854,
#   'ALL': 0.275838,
#   'EUR': 0.002366,
#   'DZD': 0.323187,
#   'USD': 0.0023,
#   'AOA': 1.011082,
#   'XCD': 0.006216,
#   'ARS': 0.347179,
#   'AMD': 0.927333,
#   'AWG': 0.00414,
#   'SHP': 0.003168,
#   'AUD': 0.003664,
#   'AZN': 0.003904,
#   'BSD': 0.0023,
#   'BHD': 0.000867,
#   'BDT': 0.233895,
#   'BBD': 0.004645,
#   'BYR': 45.081305,
#   'BZD': 0.004637,
#   'XOF': 1.553117,
#   'BMD': 0.0023,
#   'BTN': 0.1893,
#   'BOB': 0.015896,
#   'BAM': 0.004631,
#   'BWP': 0.03088,
#   'BRL': 0.012127,
#   'BND': 0.003303,
#   'BGN': 0.004627,
#   'BIF': 4.753302,
#   'CVE': 0.261068,
#   'KHR': 9.499122,
#   'XAF': 1.553133,
#   'CAD': 0.003178,
#   'KYD': 0.001917,
#   'ANG': 0.004146,
#   'CLP': 2.169561,
#   'CNY': 0.016533,
#   'COP': 10.595349,
#   'KMF': 1.169296,
#   'CDF': 4.708237,
#   'NZD': 0.004096,
#   'CRC': 1.448473,
#   'HRK': 0.017816,
#   'CUP': 0.060952,
#   'CZK': 0.058196,
#   'DKK': 0.0176,
#   'DJF': 0.409516,
#   'DOP': 0.123595,
#   'EGP': 0.045268,
#   'SVC': 0.02013,
#   'ERN': 0.034501,
#   'ETB': 0.121694,
#   'FKP': 0.002062,
#   'FJD': 0.005344,
#   'XPF': 0.284052,
#   'GMD': 0.129401,
#   'GEL': 0.006394,
#   'GHS': 0.024845,
#   'GIP': 0.002062,
#   'GGP': 0.002062,
#   'GNF': 19.865546,
#   'GYD': 0.481294,
#   'HTG': 0.285272,
#   'HNL': 0.056833,
#   'HKD': 0.018054,
#   'HUF': 1.023357,
#   'ISK': 0.332453,
#   'INR': 0.189351,
#   'IDR': 35.317638,
#   'IRR': 97.522825,
#   'IQD': 3.357654,
#   'GBP': 0.002062,
#   'ILS': 0.008221,
#   'JMD': 0.351701,
#   'JPY': 0.337698,
#   'JOD': 0.001633,
#   'KZT': 1.101153,
#   'KES': 0.278309,
#   'KPW': 2.07006,
#   'KRW': 3.290234,
#   'KWD': 0.000714,
#   'KGS': 0.192251,
#   'LAK': 38.70534,
#   'LVL': 0.001391,
#   'LBP': 3.478298,
#   'LSL': 0.041585,
#   'LRD': 0.353406,
#   'LYD': 0.011598,
#   'CHF': 0.002296,
#   'LTL': 0.006791,
#   'MOP': 0.018601,
#   'MKD': 0.145883,
#   'MWK': 2.361357,
#   'MYR': 0.010791,
#   'MVR': 0.035537,
#   'MRO': 0.821123,
#   'MUR': 0.100972,
#   'MXN': 0.045942,
#   'MDL': 0.044687,
#   'MNT': 7.718569,
#   'MAD': 0.025326,
#   'MZN': 0.146814,
#   'MMK': 4.831184,
#   'NAD': 0.041585,
#   'NPR': 0.302893,
#   'NIO': 0.082752,
#   'NGN': 1,
#   'NOK': 0.024563,
#   'OMR': 0.000884,
#   'PKR': 0.500948,
#   'PAB': 0.0023,
#   'PGK': 0.008108,
#   'PYG': 16.376281,
#   'PEN': 0.009138,
#   'PHP': 0.135558,
#   'PLN': 0.011463,
#   'QAR': 0.008375,
#   'RON': 0.011679,
#   'RUB': 0.146342,
#   'RWF': 2.450868,
#   'WST': 0.006535,
#   'STD': 47.606735,
#   'SAR': 0.008645,
#   'RSD': 0.277469,
#   'SCR': 0.029935,
#   'SLL': 37.836096,
#   'SGD': 0.003298,
#   'SBD': 0.018746,
#   'SOS': 1.307617,
#   'ZAR': 0.042035,
#   'LKR': 0.84314,
#   'SDG': 1.305265,
#   'SRD': 0.064618,
#   'SZL': 0.041885,
#   'SEK': 0.026027,
#   'SYP': 5.778987,
#   'TWD': 0.073282,
#   'TJS': 0.02335,
#   'TZS': 5.363756,
#   'THB': 0.087072,
#   'TOP': 0.005636,
#   'TTD': 0.015619,
#   'TND': 0.007543,
#   'TRY': 0.042754,
#   'TMT': 0.00805,
#   'UGX': 8.822297,
#   'UAH': 0.084964,
#   'AED': 0.008448,
#   'UYU': 0.094492,
#   'UZS': 25.524819,
#   'VUV': 0.287435,
#   'VND': 55.535108,
#   'YER': 0.575592,
#   'ZMW': 0.036521}}

# %%
def compile_currencies():
    country_list = [("Afghanistan", "AFN", "AF"), 
    ("Albania","ALL", "AL"),
    ["Aland Island", "EUR", "AX"],
    ("Algeria","DZD", "DZ"),
    ("American-Samoa","USD", "AS"),
    ("Andorra","EUR", "AD"),
    ("Angola","AOA", "AO"),
    ("Anguilla","XCD", "AI"),
    ("Antigua-Barbuda","XCD", "AG"),
    ("Argentina","ARS", "AR"),
    ("Armenia","AMD", "AM"),
    ("Aruba","AWG", "AW"),
    ["Ascension Island", "SHP", "AC"],
    ("Australia","AUD", "AU"),
    ("Austria","EUR", "AT"),
    ("Azerbaijan","AZN", "AZ"),
    ("Bahamas","BSD", "BS"),
    ("Bahrain","BHD", "BH"),
    ("Bangladesh","BDT", "BD"),
    ("Barbados","BBD", "BB"),
    ("Belarus","BYR", "BY"),
    ("Belgium","EUR", "BE"),
    ("Belize","BZD", "BZ"),
    ("Benin","XOF", "BJ"),
    ("Bermuda","BMD", "BM"),
    ("Bhutan","BTN", "BT"),
    ("Bolivia","BOB", "BO"),
    ("Bosnia-Herzegovina","BAM", "BA"),
    ("Botswana","BWP", "BW"),
    ("Brazil","BRL", "BR"),
    ("British Indian Ocean Territory","USD", "IO"),
    ("Brunei Darussalam","BND", "BN"),
    ("Bulgaria","BGN", "BG"),
    ("Burkina Faso","XOF", "BF"),
    ("Burundi","BIF", "BI"),
    ("Cape Verde","CVE", "CV"),
    ("Cambodia","KHR", "KH"),
    ("Cameroon","XAF", "CM"),
    ("Canada","CAD", "CA"),
    ("Cayman Islands","KYD", "KY"),
    ("Central African Republic","XAF", "CF"),
    ["Carribean Neatherlands", "ANG", "BO"],
    ("Chad","XAF", "TD"),
    ("Chile","CLP", "CL"),
    ("China","CNY", "CN"),
    ("Christmas Island","AUD", "CX"),
    ("Cocos (Keeling) Islands","AUD", "CC"),
    ("Colombia","COP", "CO"),
    ("Comoros","KMF", "KM"),
    ("Congo","XAF", "CG"),
    ("Congo, Dem. Republic","CDF", "CD"),
    ("Cook Islands","NZD", "CK"),
    ("Costa Rica","CRC", "CR"),
    ("Croatia","HRK", "HR"),
    ("Cuba","CUP", "CU"),
    ("Curaçao","ANG", "CW"),
    ("Cyprus","EUR", "CY"),
    ("Czechia","CZK", "CZ"),
    ("Côte d'Ivoire","XOF", "CI"),
    ("Denmark","DKK", "DK"),
    ("Djibouti","DJF", "DJ"),
    ("Dominica","XCD", "DM"),
    ("Dominican Republic","DOP", "DO"),
    ("Ecuador","ECS", "EC"),
    ["East Timor", "USD", "TL"],
    ("Egypt","EGP", "EG"),
    ("El Salvador","SVC", "SV"),
    ("Equatorial Guinea","XAF", "GO"),
    ("Eritrea","ERN", "ER"),
    ("Estonia","EUR", "EE"),
    ("Ethiopia","ETB", "ET"),
    ("Falkland Islands (Malvinas)","FKP", "FK"),
    ("Faroe Islands","DKK", "FO"),
    ("Fiji","FJD", "FJ"),
    ("Finland","EUR", "FI"),
    ("France","EUR", "FR"),
    ("French Guiana","EUR", "GF"),
    ("French Polynesia","XPF", "PF"),
    ("Gabon","XAF", "GA"),
    ("Gambia","GMD", "GM"),
    ("Georgia","GEL", "GE"),
    ("Germany","EUR", "DE"),
    ("Ghana","GHS", "GH"),
    ("Gibraltar","GIP", "GI"),
    ("Greece","EUR", "GR"),
    ("Greenland","DKK", "GL"),
    ("Grenada","XCD", "GD"),
    ("Guadeloupe (French)","EUR", "GP"),
    ("Guam (USA)","USD", "GU"),
    ("Guatemala","QTQ", "GT"),
    ("Guernsey","GGP", "GG"),
    ("Guinea","GNF", "GN"),
    ("Guinea Bissau","GWP", "GW"),
    ("Guyana","GYD", "GY"),
    ("Haiti","HTG", "HT"),
    ("Heard Island and McDonald Islands","AUD", "HM"),
    ("Honduras","HNL", "HN"),
    ("Hong Kong","HKD", "HK"),
    ("Hungary","HUF", "HU"),
    ("Iceland","ISK", "IS"),
    ("India","INR", "IN"),
    ("Indonesia","IDR", "ID"),
    ("Iran","IRR", "IR"),
    ("Iraq","IQD", "IQ"),
    ("Ireland","EUR", "IE"),
    ("Isle of Man","GBP", "IM"),
    ("Israel","ILS", "IL"),
    ("Italy","EUR", "IT"),
    ("Jamaica","JMD", "JM"),
    ("Japan","JPY", "JP"),
    ("Jersey","GBP", "JE"),
    ("Jordan","JOD", "JO"),
    ("Kazakhstan","KZT", "KZ"),
    ("Kenya","KES", "KE"),
    ("Kiribati","AUD", "KI"),
    ("Korea-North","KPW", "KP"),
    ("Korea-South","KRW", "KR"),
    ("Kuwait","KWD", "KW"),
    ["Kosovo", "EUR", "XK"],
    ("Kyrgyzstan","KGS", "KG"),
    ("Laos","LAK", "LA"),
    ("Latvia","LVL", "LV"),
    ("Lebanon","LBP", "LB"),
    ("Lesotho","LSL", "LS"),
    ("Liberia","LRD", "LR"),
    ("Libya","LYD", "LY"),
    ("Liechtenstein","CHF", "LI"),
    ("Lithuania","LTL", "LT"),
    ("Luxembourg","EUR", "LU"),
    ("Macao","MOP", "MO"),
    ("Madagascar","MGF", "MG"),
    ["Macedonia", "MKD", "MK"],
    ("Malawi","MWK", "MW"),
    ("Malaysia","MYR", "MY"),
    ("Maldives","MVR", "MV"),
    ("Mali","XOF", "ML"),
    ("Malta","EUR", "MT"),
    ("Marshall Islands","USD", "MH"),
    ("Martinique (French)","EUR", "MQ"),
    ("Mauritania","MRO", "MR"),
    ("Mauritius","MUR", "MU"),
    ("Mayotte","EUR", "YT"),
    ("Mexico","MXN", "MX"),
    ("Micronesia","USD", "FM"),
    ("Moldova","MDL", "MD"),
    ("Monaco","EUR", "MC"),
    ("Mongolia","MNT", "MN"),
    ("Montenegro","EUR", "ME"),
    ("Montserrat","XCD", "MS"),
    ("Morocco","MAD", "MA"),
    ("Mozambique","MZN", "MZ"),
    ("Myanmar","MMK", "MM"),
    ("Namibia","NAD", "NA"),
    ("Nauru","AUD", "NR"),
    ("Nepal","NPR", "NP"),
    ("Netherlands","EUR", "NL"),
    ("New Caledonia (French)","XPF", "NC"),
    ("New Zealand","NZD", "NZ"),
    ("Nicaragua","NIO", "NI"),
    ("Niger","XOF", "NE"),
    ("Nigeria","NGN", "NG"),
    ("Niue","NZD", "NU"),
    ("Norfolk Island","AUD", "NF"),
    ("Northern Mariana Islands","USD", "MP"),
    ("Norway","NOK", "NO"),
    ("Oman","OMR", "OM"),
    ["Pakistan","PKR", "PK"],
    ["Palau","USD", "PW"],
    ["Panama","PAB", "PA"],
    ["Palestinian Territories", "ILS", "PS"],
    ["Papua New Guinea","PGK", "PG"],
    ["Paraguay","PYG", "PY"],
    ["Peru","PEN", "PE"],
    ["Philippines","PHP", "PH"],
    ["Poland","PLN", "PL"],
    ["Portugal","EUR", "PT"],
    ["Puerto Rico","USD", "PR"],
    ["Qatar","QAR", "QA"],
    ["Reunion (French)","EUR", "RE"],
    ["Romania","RON", "RO"],
    ["Russia","RUB", "RU"],
    ["Rwanda","RWF", "RW"],
    ["Saint Helena","SHP", "SH"],
    ["Saint Kitts & Nevis Anguilla","XCD", "KN"],
    ["Saint Lucia","XCD", "LC"],
    ["Saint Pierre and Miquelon","EUR", "PM"],
    ["Saint Vincent & Grenadines","XCD", "VC"],
    ["Saint Martin", "XCD", "MF"],
    ["Saint Barthélemy", "XCD", "BL"],
    ["Samoa","WST", "WS"],
    ["San Marino","EUR", "SM"],
    ["Sao Tome and Principe","STD", "ST"],
    ["Saudi Arabia","SAR", "SA"],
    ["Senegal",	"XOF", "SN"],
    ["Serbia","RSD", "RS"],
    ["Seychelles","SCR", "SC"],
    ["Sierra Leone","SLL", "SL"],
    ["Singapore","SGD", "SG"],
    ["Slovakia","EUR", "SK"],
    ["Slovenia","EUR", "SI"],
    ["Solomon Islands","SBD", "SB"],
    ["Somalia","SOS", "SO"],
    ["Sint Maarten", "XCD", "SX"],
    ["South Africa","ZAR", "ZA"],
    ["South Georgia & South Sandwich Islands","GBP", "GS"],
    ["South Sudan","SSP", "SS"],
    ["Spain","EUR", "ES"],
    ["Sri Lanka", "LKR", "LK"],
    ["Sudan","SDG", "SD"],
    ["Suriname","SRD", "SR"],
    ["Svalbard and Jan Mayen Islands","NOK", "SJ"],
    ["Eswatini", "SZL", "SZ"],
    ["Sweden","SEK", "SEK"],
    ["Switzerland","CHF", "CH"],
    ["Syria","SYP", "SY"],
    ["Taiwan", "TWD", "TW"],
    ["Tajikistan","TJS", "TJ"],
    ["Tanzania","TZS", "TZ"],
    ["Thailand","THB", "TH"],
    ["Togo","XOF", "TOGO"],
    ["Tokelau",	"NZD", "TK"],
    ["Tonga","TOP", "TO"],
    ["Trinidad and Tobago","TTD", "TT"],
    ["Tunisia","TND", "TN"],
    ["Turkey","TRY", "TR"],
    ["Turkmenistan","TMT", "TM"],
    ["Turks and Caicos Islands","USD", "TC"],
    ["Tuvalu",	"AUD", "TV"],
    ["USA","USD", "US"],
    ["Uganda","UGX", "UG"],
    ["Ukraine","UAH", "UA"],
    ["United Arab Emirates","AED", "AE"],
    ["United Kingdom", "GBP", "GB"],
    ["Uruguay","UYU", "UY"],
    ["Uzbekistan",	"UZS", "UZ"],
    ["Vanuatu","VUV", "VU"],
    ["Vatican City", "VAL", "VA"],
    ["Venezuela", "VEF", "VE"],
    ["Vietnam","VND", "VN"],
    ["Virgin Islands (British)","USD", "VG"],
    ["Virgin Islands (USA)","USD", "VI"],
    ["Wallis and Futuna Islands", "XPF", "WF"],
    ["Western Sahara", "MAD", "EH"],
    ["Yemen", "YER", "YE"],
    ["Zambia","ZMW", "ZM"],
    ["Zimbabwe","ZWD", "ZW"]]
    count_ = []
    currencies = []
    for i in country_list:
        country_dict = {}
        country_dict["country"] = i[0]
        country_dict["currency"] = i[1]
        country_dict["symbol"] = i[2]
        count_.append(country_dict)
        if i[1] in currencies:
            pass
        else:
            currencies.append(i[1])
    #currencies = []
    joined_c = ",".join(currencies)
    return {"currencies":joined_c, "country_list":count_}

# %%
curr = compile_currencies()#["currencies"]

# %%
curr
# Out:
# {'currencies': 'AFN,ALL,EUR,DZD,USD,AOA,XCD,ARS,AMD,AWG,SHP,AUD,AZN,BSD,BHD,BDT,BBD,BYR,BZD,XOF,BMD,BTN,BOB,BAM,BWP,BRL,BND,BGN,BIF,CVE,KHR,XAF,CAD,KYD,ANG,CLP,CNY,COP,KMF,CDF,NZD,CRC,HRK,CUP,CZK,DKK,DJF,DOP,ECS,EGP,SVC,ERN,ETB,FKP,FJD,XPF,GMD,GEL,GHS,GIP,QTQ,GGP,GNF,GWP,GYD,HTG,HNL,HKD,HUF,ISK,INR,IDR,IRR,IQD,GBP,ILS,JMD,JPY,JOD,KZT,KES,KPW,KRW,KWD,KGS,LAK,LVL,LBP,LSL,LRD,LYD,CHF,LTL,MOP,MGF,MKD,MWK,MYR,MVR,MRO,MUR,MXN,MDL,MNT,MAD,MZN,MMK,NAD,NPR,NIO,NGN,NOK,OMR,PKR,PAB,PGK,PYG,PEN,PHP,PLN,QAR,RON,RUB,RWF,WST,STD,SAR,RSD,SCR,SLL,SGD,SBD,SOS,ZAR,SSP,LKR,SDG,SRD,SZL,SEK,SYP,TWD,TJS,TZS,THB,TOP,TTD,TND,TRY,TMT,UGX,UAH,AED,UYU,UZS,VUV,VAL,VEF,VND,YER,ZMW,ZWD',
#  'country_list': [{'country': 'Afghanistan',
#    'currency': 'AFN',
#    'symbol': 'AF'},
#   {'country': 'Albania', 'currency': 'ALL', 'symbol': 'AL'},
#   {'country': 'Aland Island', 'currency': 'EUR', 'symbol': 'AX'},
#   {'country': 'Algeria', 'currency': 'DZD', 'symbol': 'DZ'},
#   {'country': 'American-Samoa', 'currency': 'USD', 'symbol': 'AS'},
#   {'country': 'Andorra', 'currency': 'EUR', 'symbol': 'AD'},
#   {'country': 'Angola', 'currency': 'AOA', 'symbol': 'AO'},
#   {'country': 'Anguilla', 'currency': 'XCD', 'symbol': 'AI'},
#   {'country': 'Antigua-Barbuda', 'currency': 'XCD', 'symbol': 'AG'},
#   {'country': 'Argentina', 'currency': 'ARS', 'symbol': 'AR'},
#   {'country': 'Armenia', 'currency': 'AMD', 'symbol': 'AM'},
#   {'country': 'Aruba', 'currency': 'AWG', 'symbol': 'AW'},
#   {'country': 'Ascension Island', 'currency': 'SHP', 'symbol': 'AC'},
#   {'country': 'Australia', 'currency': 'AUD', 'symbol': 'AU'},
#   {'country': 'Austria', 'currency': 'EUR', 'symbol': 'AT'},
#   {'country': 'Azerbaijan', 'currency': 'AZN', 'symbol': 'AZ'},
#   {'country': 'Bahamas', 'currency': 'BSD', 'symbol': 'BS'},
#   {'country': 'Bahrain', 'currency': 'BHD', 'symbol': 'BH'},
#   {'country': 'Bangladesh', 'currency': 'BDT', 'symbol': 'BD'},
#   {'country': 'Barbados', 'currency': 'BBD', 'symbol': 'BB'},
#   {'country': 'Belarus', 'currency': 'BYR', 'symbol': 'BY'},
#   {'country': 'Belgium', 'currency': 'EUR', 'symbol': 'BE'},
#   {'country': 'Belize', 'currency': 'BZD', 'symbol': 'BZ'},
#   {'country': 'Benin', 'currency': 'XOF', 'symbol': 'BJ'},
#   {'country': 'Bermuda', 'currency': 'BMD', 'symbol': 'BM'},
#   {'country': 'Bhutan', 'currency': 'BTN', 'symbol': 'BT'},
#   {'country': 'Bolivia', 'currency': 'BOB', 'symbol': 'BO'},
#   {'country': 'Bosnia-Herzegovina', 'currency': 'BAM', 'symbol': 'BA'},
#   {'country': 'Botswana', 'currency': 'BWP', 'symbol': 'BW'},
#   {'country': 'Brazil', 'currency': 'BRL', 'symbol': 'BR'},
#   {'country': 'British Indian Ocean Territory',
#    'currency': 'USD',
#    'symbol': 'IO'},
#   {'country': 'Brunei Darussalam', 'currency': 'BND', 'symbol': 'BN'},
#   {'country': 'Bulgaria', 'currency': 'BGN', 'symbol': 'BG'},
#   {'country': 'Burkina Faso', 'currency': 'XOF', 'symbol': 'BF'},
#   {'country': 'Burundi', 'currency': 'BIF', 'symbol': 'BI'},
#   {'country': 'Cape Verde', 'currency': 'CVE', 'symbol': 'CV'},
#   {'country': 'Cambodia', 'currency': 'KHR', 'symbol': 'KH'},
#   {'country': 'Cameroon', 'currency': 'XAF', 'symbol': 'CM'},
#   {'country': 'Canada', 'currency': 'CAD', 'symbol': 'CA'},
#   {'country': 'Cayman Islands', 'currency': 'KYD', 'symbol': 'KY'},
#   {'country': 'Central African Republic', 'currency': 'XAF', 'symbol': 'CF'},
#   {'country': 'Carribean Neatherlands', 'currency': 'ANG', 'symbol': 'BO'},
#   {'country': 'Chad', 'currency': 'XAF', 'symbol': 'TD'},
#   {'country': 'Chile', 'currency': 'CLP', 'symbol': 'CL'},
#   {'country': 'China', 'currency': 'CNY', 'symbol': 'CN'},
#   {'country': 'Christmas Island', 'currency': 'AUD', 'symbol': 'CX'},
#   {'country': 'Cocos (Keeling) Islands', 'currency': 'AUD', 'symbol': 'CC'},
#   {'country': 'Colombia', 'currency': 'COP', 'symbol': 'CO'},
#   {'country': 'Comoros', 'currency': 'KMF', 'symbol': 'KM'},
#   {'country': 'Congo', 'currency': 'XAF', 'symbol': 'CG'},
#   {'country': 'Congo, Dem. Republic', 'currency': 'CDF', 'symbol': 'CD'},
#   {'country': 'Cook Islands', 'currency': 'NZD', 'symbol': 'CK'},
#   {'country': 'Costa Rica', 'currency': 'CRC', 'symbol': 'CR'},
#   {'country': 'Croatia', 'currency': 'HRK', 'symbol': 'HR'},
#   {'country': 'Cuba', 'currency': 'CUP', 'symbol': 'CU'},
#   {'country': 'Curaçao', 'currency': 'ANG', 'symbol': 'CW'},
#   {'country': 'Cyprus', 'currency': 'EUR', 'symbol': 'CY'},
#   {'country': 'Czechia', 'currency': 'CZK', 'symbol': 'CZ'},
#   {'country': "Côte d'Ivoire", 'currency': 'XOF', 'symbol': 'CI'},
#   {'country': 'Denmark', 'currency': 'DKK', 'symbol': 'DK'},
#   {'country': 'Djibouti', 'currency': 'DJF', 'symbol': 'DJ'},
#   {'country': 'Dominica', 'currency': 'XCD', 'symbol': 'DM'},
#   {'country': 'Dominican Republic', 'currency': 'DOP', 'symbol': 'DO'},
#   {'country': 'Ecuador', 'currency': 'ECS', 'symbol': 'EC'},
#   {'country': 'East Timor', 'currency': 'USD', 'symbol': 'TL'},
#   {'country': 'Egypt', 'currency': 'EGP', 'symbol': 'EG'},
#   {'country': 'El Salvador', 'currency': 'SVC', 'symbol': 'SV'},
#   {'country': 'Equatorial Guinea', 'currency': 'XAF', 'symbol': 'GO'},
#   {'country': 'Eritrea', 'currency': 'ERN', 'symbol': 'ER'},
#   {'country': 'Estonia', 'currency': 'EUR', 'symbol': 'EE'},
#   {'country': 'Ethiopia', 'currency': 'ETB', 'symbol': 'ET'},
#   {'country': 'Falkland Islands (Malvinas)',
#    'currency': 'FKP',
#    'symbol': 'FK'},
#   {'country': 'Faroe Islands', 'currency': 'DKK', 'symbol': 'FO'},
#   {'country': 'Fiji', 'currency': 'FJD', 'symbol': 'FJ'},
#   {'country': 'Finland', 'currency': 'EUR', 'symbol': 'FI'},
#   {'country': 'France', 'currency': 'EUR', 'symbol': 'FR'},
#   {'country': 'French Guiana', 'currency': 'EUR', 'symbol': 'GF'},
#   {'country': 'French Polynesia', 'currency': 'XPF', 'symbol': 'PF'},
#   {'country': 'Gabon', 'currency': 'XAF', 'symbol': 'GA'},
#   {'country': 'Gambia', 'currency': 'GMD', 'symbol': 'GM'},
#   {'country': 'Georgia', 'currency': 'GEL', 'symbol': 'GE'},
#   {'country': 'Germany', 'currency': 'EUR', 'symbol': 'DE'},
#   {'country': 'Ghana', 'currency': 'GHS', 'symbol': 'GH'},
#   {'country': 'Gibraltar', 'currency': 'GIP', 'symbol': 'GI'},
#   {'country': 'Greece', 'currency': 'EUR', 'symbol': 'GR'},
#   {'country': 'Greenland', 'currency': 'DKK', 'symbol': 'GL'},
#   {'country': 'Grenada', 'currency': 'XCD', 'symbol': 'GD'},
#   {'country': 'Guadeloupe (French)', 'currency': 'EUR', 'symbol': 'GP'},
#   {'country': 'Guam (USA)', 'currency': 'USD', 'symbol': 'GU'},
#   {'country': 'Guatemala', 'currency': 'QTQ', 'symbol': 'GT'},
#   {'country': 'Guernsey', 'currency': 'GGP', 'symbol': 'GG'},
#   {'country': 'Guinea', 'currency': 'GNF', 'symbol': 'GN'},
#   {'country': 'Guinea Bissau', 'currency': 'GWP', 'symbol': 'GW'},
#   {'country': 'Guyana', 'currency': 'GYD', 'symbol': 'GY'},
#   {'country': 'Haiti', 'currency': 'HTG', 'symbol': 'HT'},
#   {'country': 'Heard Island and McDonald Islands',
#    'currency': 'AUD',
#    'symbol': 'HM'},
#   {'country': 'Honduras', 'currency': 'HNL', 'symbol': 'HN'},
#   {'country': 'Hong Kong', 'currency': 'HKD', 'symbol': 'HK'},
#   {'country': 'Hungary', 'currency': 'HUF', 'symbol': 'HU'},
#   {'country': 'Iceland', 'currency': 'ISK', 'symbol': 'IS'},
#   {'country': 'India', 'currency': 'INR', 'symbol': 'IN'},
#   {'country': 'Indonesia', 'currency': 'IDR', 'symbol': 'ID'},
#   {'country': 'Iran', 'currency': 'IRR', 'symbol': 'IR'},
#   {'country': 'Iraq', 'currency': 'IQD', 'symbol': 'IQ'},
#   {'country': 'Ireland', 'currency': 'EUR', 'symbol': 'IE'},
#   {'country': 'Isle of Man', 'currency': 'GBP', 'symbol': 'IM'},
#   {'country': 'Israel', 'currency': 'ILS', 'symbol': 'IL'},
#   {'country': 'Italy', 'currency': 'EUR', 'symbol': 'IT'},
#   {'country': 'Jamaica', 'currency': 'JMD', 'symbol': 'JM'},
#   {'country': 'Japan', 'currency': 'JPY', 'symbol': 'JP'},
#   {'country': 'Jersey', 'currency': 'GBP', 'symbol': 'JE'},
#   {'country': 'Jordan', 'currency': 'JOD', 'symbol': 'JO'},
#   {'country': 'Kazakhstan', 'currency': 'KZT', 'symbol': 'KZ'},
#   {'country': 'Kenya', 'currency': 'KES', 'symbol': 'KE'},
#   {'country': 'Kiribati', 'currency': 'AUD', 'symbol': 'KI'},
#   {'country': 'Korea-North', 'currency': 'KPW', 'symbol': 'KP'},
#   {'country': 'Korea-South', 'currency': 'KRW', 'symbol': 'KR'},
#   {'country': 'Kuwait', 'currency': 'KWD', 'symbol': 'KW'},
#   {'country': 'Kosovo', 'currency': 'EUR', 'symbol': 'XK'},
#   {'country': 'Kyrgyzstan', 'currency': 'KGS', 'symbol': 'KG'},
#   {'country': 'Laos', 'currency': 'LAK', 'symbol': 'LA'},
#   {'country': 'Latvia', 'currency': 'LVL', 'symbol': 'LV'},
#   {'country': 'Lebanon', 'currency': 'LBP', 'symbol': 'LB'},
#   {'country': 'Lesotho', 'currency': 'LSL', 'symbol': 'LS'},
#   {'country': 'Liberia', 'currency': 'LRD', 'symbol': 'LR'},
#   {'country': 'Libya', 'currency': 'LYD', 'symbol': 'LY'},
#   {'country': 'Liechtenstein', 'currency': 'CHF', 'symbol': 'LI'},
#   {'country': 'Lithuania', 'currency': 'LTL', 'symbol': 'LT'},
#   {'country': 'Luxembourg', 'currency': 'EUR', 'symbol': 'LU'},
#   {'country': 'Macao', 'currency': 'MOP', 'symbol': 'MO'},
#   {'country': 'Madagascar', 'currency': 'MGF', 'symbol': 'MG'},
#   {'country': 'Macedonia', 'currency': 'MKD', 'symbol': 'MK'},
#   {'country': 'Malawi', 'currency': 'MWK', 'symbol': 'MW'},
#   {'country': 'Malaysia', 'currency': 'MYR', 'symbol': 'MY'},
#   {'country': 'Maldives', 'currency': 'MVR', 'symbol': 'MV'},
#   {'country': 'Mali', 'currency': 'XOF', 'symbol': 'ML'},
#   {'country': 'Malta', 'currency': 'EUR', 'symbol': 'MT'},
#   {'country': 'Marshall Islands', 'currency': 'USD', 'symbol': 'MH'},
#   {'country': 'Martinique (French)', 'currency': 'EUR', 'symbol': 'MQ'},
#   {'country': 'Mauritania', 'currency': 'MRO', 'symbol': 'MR'},
#   {'country': 'Mauritius', 'currency': 'MUR', 'symbol': 'MU'},
#   {'country': 'Mayotte', 'currency': 'EUR', 'symbol': 'YT'},
#   {'country': 'Mexico', 'currency': 'MXN', 'symbol': 'MX'},
#   {'country': 'Micronesia', 'currency': 'USD', 'symbol': 'FM'},
#   {'country': 'Moldova', 'currency': 'MDL', 'symbol': 'MD'},
#   {'country': 'Monaco', 'currency': 'EUR', 'symbol': 'MC'},
#   {'country': 'Mongolia', 'currency': 'MNT', 'symbol': 'MN'},
#   {'country': 'Montenegro', 'currency': 'EUR', 'symbol': 'ME'},
#   {'country': 'Montserrat', 'currency': 'XCD', 'symbol': 'MS'},
#   {'country': 'Morocco', 'currency': 'MAD', 'symbol': 'MA'},
#   {'country': 'Mozambique', 'currency': 'MZN', 'symbol': 'MZ'},
#   {'country': 'Myanmar', 'currency': 'MMK', 'symbol': 'MM'},
#   {'country': 'Namibia', 'currency': 'NAD', 'symbol': 'NA'},
#   {'country': 'Nauru', 'currency': 'AUD', 'symbol': 'NR'},
#   {'country': 'Nepal', 'currency': 'NPR', 'symbol': 'NP'},
#   {'country': 'Netherlands', 'currency': 'EUR', 'symbol': 'NL'},
#   {'country': 'New Caledonia (French)', 'currency': 'XPF', 'symbol': 'NC'},
#   {'country': 'New Zealand', 'currency': 'NZD', 'symbol': 'NZ'},
#   {'country': 'Nicaragua', 'currency': 'NIO', 'symbol': 'NI'},
#   {'country': 'Niger', 'currency': 'XOF', 'symbol': 'NE'},
#   {'country': 'Nigeria', 'currency': 'NGN', 'symbol': 'NG'},
#   {'country': 'Niue', 'currency': 'NZD', 'symbol': 'NU'},
#   {'country': 'Norfolk Island', 'currency': 'AUD', 'symbol': 'NF'},
#   {'country': 'Northern Mariana Islands', 'currency': 'USD', 'symbol': 'MP'},
#   {'country': 'Norway', 'currency': 'NOK', 'symbol': 'NO'},
#   {'country': 'Oman', 'currency': 'OMR', 'symbol': 'OM'},
#   {'country': 'Pakistan', 'currency': 'PKR', 'symbol': 'PK'},
#   {'country': 'Palau', 'currency': 'USD', 'symbol': 'PW'},
#   {'country': 'Panama', 'currency': 'PAB', 'symbol': 'PA'},
#   {'country': 'Palestinian Territories', 'currency': 'ILS', 'symbol': 'PS'},
#   {'country': 'Papua New Guinea', 'currency': 'PGK', 'symbol': 'PG'},
#   {'country': 'Paraguay', 'currency': 'PYG', 'symbol': 'PY'},
#   {'country': 'Peru', 'currency': 'PEN', 'symbol': 'PE'},
#   {'country': 'Philippines', 'currency': 'PHP', 'symbol': 'PH'},
#   {'country': 'Poland', 'currency': 'PLN', 'symbol': 'PL'},
#   {'country': 'Portugal', 'currency': 'EUR', 'symbol': 'PT'},
#   {'country': 'Puerto Rico', 'currency': 'USD', 'symbol': 'PR'},
#   {'country': 'Qatar', 'currency': 'QAR', 'symbol': 'QA'},
#   {'country': 'Reunion (French)', 'currency': 'EUR', 'symbol': 'RE'},
#   {'country': 'Romania', 'currency': 'RON', 'symbol': 'RO'},
#   {'country': 'Russia', 'currency': 'RUB', 'symbol': 'RU'},
#   {'country': 'Rwanda', 'currency': 'RWF', 'symbol': 'RW'},
#   {'country': 'Saint Helena', 'currency': 'SHP', 'symbol': 'SH'},
#   {'country': 'Saint Kitts & Nevis Anguilla',
#    'currency': 'XCD',
#    'symbol': 'KN'},
#   {'country': 'Saint Lucia', 'currency': 'XCD', 'symbol': 'LC'},
#   {'country': 'Saint Pierre and Miquelon', 'currency': 'EUR', 'symbol': 'PM'},
#   {'country': 'Saint Vincent & Grenadines', 'currency': 'XCD', 'symbol': 'VC'},
#   {'country': 'Saint Martin', 'currency': 'XCD', 'symbol': 'MF'},
#   {'country': 'Saint Barthélemy', 'currency': 'XCD', 'symbol': 'BL'},
#   {'country': 'Samoa', 'currency': 'WST', 'symbol': 'WS'},
#   {'country': 'San Marino', 'currency': 'EUR', 'symbol': 'SM'},
#   {'country': 'Sao Tome and Principe', 'currency': 'STD', 'symbol': 'ST'},
#   {'country': 'Saudi Arabia', 'currency': 'SAR', 'symbol': 'SA'},
#   {'country': 'Senegal', 'currency': 'XOF', 'symbol': 'SN'},
#   {'country': 'Serbia', 'currency': 'RSD', 'symbol': 'RS'},
#   {'country': 'Seychelles', 'currency': 'SCR', 'symbol': 'SC'},
#   {'country': 'Sierra Leone', 'currency': 'SLL', 'symbol': 'SL'},
#   {'country': 'Singapore', 'currency': 'SGD', 'symbol': 'SG'},
#   {'country': 'Slovakia', 'currency': 'EUR', 'symbol': 'SK'},
#   {'country': 'Slovenia', 'currency': 'EUR', 'symbol': 'SI'},
#   {'country': 'Solomon Islands', 'currency': 'SBD', 'symbol': 'SB'},
#   {'country': 'Somalia', 'currency': 'SOS', 'symbol': 'SO'},
#   {'country': 'Sint Maarten', 'currency': 'XCD', 'symbol': 'SX'},
#   {'country': 'South Africa', 'currency': 'ZAR', 'symbol': 'ZA'},
#   {'country': 'South Georgia & South Sandwich Islands',
#    'currency': 'GBP',
#    'symbol': 'GS'},
#   {'country': 'South Sudan', 'currency': 'SSP', 'symbol': 'SS'},
#   {'country': 'Spain', 'currency': 'EUR', 'symbol': 'ES'},
#   {'country': 'Sri Lanka', 'currency': 'LKR', 'symbol': 'LK'},
#   {'country': 'Sudan', 'currency': 'SDG', 'symbol': 'SD'},
#   {'country': 'Suriname', 'currency': 'SRD', 'symbol': 'SR'},
#   {'country': 'Svalbard and Jan Mayen Islands',
#    'currency': 'NOK',
#    'symbol': 'SJ'},
#   {'country': 'Eswatini', 'currency': 'SZL', 'symbol': 'SZ'},
#   {'country': 'Sweden', 'currency': 'SEK', 'symbol': 'SEK'},
#   {'country': 'Switzerland', 'currency': 'CHF', 'symbol': 'CH'},
#   {'country': 'Syria', 'currency': 'SYP', 'symbol': 'SY'},
#   {'country': 'Taiwan', 'currency': 'TWD', 'symbol': 'TW'},
#   {'country': 'Tajikistan', 'currency': 'TJS', 'symbol': 'TJ'},
#   {'country': 'Tanzania', 'currency': 'TZS', 'symbol': 'TZ'},
#   {'country': 'Thailand', 'currency': 'THB', 'symbol': 'TH'},
#   {'country': 'Togo', 'currency': 'XOF', 'symbol': 'TOGO'},
#   {'country': 'Tokelau', 'currency': 'NZD', 'symbol': 'TK'},
#   {'country': 'Tonga', 'currency': 'TOP', 'symbol': 'TO'},
#   {'country': 'Trinidad and Tobago', 'currency': 'TTD', 'symbol': 'TT'},
#   {'country': 'Tunisia', 'currency': 'TND', 'symbol': 'TN'},
#   {'country': 'Turkey', 'currency': 'TRY', 'symbol': 'TR'},
#   {'country': 'Turkmenistan', 'currency': 'TMT', 'symbol': 'TM'},
#   {'country': 'Turks and Caicos Islands', 'currency': 'USD', 'symbol': 'TC'},
#   {'country': 'Tuvalu', 'currency': 'AUD', 'symbol': 'TV'},
#   {'country': 'USA', 'currency': 'USD', 'symbol': 'US'},
#   {'country': 'Uganda', 'currency': 'UGX', 'symbol': 'UG'},
#   {'country': 'Ukraine', 'currency': 'UAH', 'symbol': 'UA'},
#   {'country': 'United Arab Emirates', 'currency': 'AED', 'symbol': 'AE'},
#   {'country': 'United Kingdom', 'currency': 'GBP', 'symbol': 'GB'},
#   {'country': 'Uruguay', 'currency': 'UYU', 'symbol': 'UY'},
#   {'country': 'Uzbekistan', 'currency': 'UZS', 'symbol': 'UZ'},
#   {'country': 'Vanuatu', 'currency': 'VUV', 'symbol': 'VU'},
#   {'country': 'Vatican City', 'currency': 'VAL', 'symbol': 'VA'},
#   {'country': 'Venezuela', 'currency': 'VEF', 'symbol': 'VE'},
#   {'country': 'Vietnam', 'currency': 'VND', 'symbol': 'VN'},
#   {'country': 'Virgin Islands (British)', 'currency': 'USD', 'symbol': 'VG'},
#   {'country': 'Virgin Islands (USA)', 'currency': 'USD', 'symbol': 'VI'},
#   {'country': 'Wallis and Futuna Islands', 'currency': 'XPF', 'symbol': 'WF'},
#   {'country': 'Western Sahara', 'currency': 'MAD', 'symbol': 'EH'},
#   {'country': 'Yemen', 'currency': 'YER', 'symbol': 'YE'},
#   {'country': 'Zambia', 'currency': 'ZMW', 'symbol': 'ZM'},
#   {'country': 'Zimbabwe', 'currency': 'ZWD', 'symbol': 'ZW'}]}

# %%
import datetime

# %%
start = datetime.datetime.now()
exp = start + datetime.timedelta(seconds=20)

# %%
datetime.datetime.now(), exp
# Out:
# (datetime.datetime(2022, 10, 14, 10, 53, 32, 469510),
#  datetime.datetime(2022, 10, 14, 10, 37, 18, 436404))

# %%
datetime.datetime.timestamp(exp)
# Out:
# 1665740238.436404

# %%
from email.message import EmailMessage
from email.mime.text import MIMEText
from mimetypes import MimeTypes
import smtplib, ssl
from email import contentmanager

#contentmanager.ContentManager.set_content()
def sendMail(email, otp_code):
        email_sender = "okoroaforc14@gmail.com"
        email_password = "clcqdzgijxaomfua"

        email_reciever = email
        #subject = "test"
        body = "test message"
        file = open("backend/verification.html")
        subject = file.read().format(code=otp_code, support_mail="okoroaforc14@gmail.com")
        
        #em = EmailMessage()
        em = MIMEText(subject,"html")
        em["From"] = email_sender
        em["To"] = email_reciever
        em["subject"] = "Test Mail"
        #em.set_content(body)

        context = ssl.create_default_context()

        with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as smtp:
            smtp.login(email_sender, email_password)
            smtp.sendmail(email_sender, email_reciever, em.as_string())

# %%
sendMail("chigozieokoroaformichael@gmail.com", "0102")

# %%
# Out:
# '<!DOCTYPE html>\n        <html>\n        <head>\n            <title></title>\n            <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n            <meta name="viewport" content="width=device-width, initial-scale=1">\n            <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n        </head>\n        <body style="background-color: #fefefe; margin: 0 !important; padding: 0 !important;">\n            <!-- HIDDEN PREHEADER TEXT -->\n            <div style="display: none; font-size: 1px; color: #fefefe; line-height: 1px; font-family: \'Lato\', Helvetica, Arial, sans-serif; max-height: 0px; max-width: 0px; opacity: 0; overflow: hidden;"> We\'re thrilled to have you here! Get ready to dive into your new account.\n            </div>\n            <table border="0" cellpadding="0" cellspacing="0" width="100%">\n                <!-- LOGO -->\n                <tr>\n                    <td bgcolor="#499fef" align="center">\n                        <table border="0" cellpadding="0" cellspacing="0" width="100%" style="max-width: 600px;">\n                            <tr>\n                                <td align="center" valign="top" style="padding: 40px 10px 40px 10px;"> </td>\n                            </tr>\n                        </table>\n                    </td>\n                </tr>\n                <tr>\n                    <td bgcolor="#499fef" align="center" style="padding: 0px 10px 0px 10px;">\n                        <table border="0" cellpadding="0" cellspacing="0" width="100%" style="max-width: 600px;">\n                            <tr>\n                                <td bgcolor="#ffffff" align="center" valign="top" style="padding: 40px 20px 20px 20px; border-radius: 4px 4px 0px 0px; color: #111111; font-family: \'Lato\', Helvetica, Arial, sans-serif; font-size: 48px; font-weight: 400; letter-spacing: 4px; line-height: 48px;">\n                                    <img src="https://res.cloudinary.com/dgpnmwhra/image/upload/v1657052121/welcome_image_gzw5yf.webp" width="125" height="120" style="display: block; border: 0px;" />\n                                </td>\n                            </tr>\n                        </table>\n                    </td>\n                </tr>\n                <tr>\n                    <td bgcolor="#f4f4f4" align="center" style="padding: 0px 10px 0px 10px;">\n                        <table border="0" cellpadding="0" cellspacing="0" width="100%" style="max-width: 600px;">\n                            <tr>\n                                <td bgcolor="#ffffff" align="left" style="padding: 20px 30px 40px 30px; color: #666666; font-family: \'Lato\', Helvetica, Arial, sans-serif; font-size: 18px; font-weight: 400; line-height: 25px;">\n                                    <p style="margin: 0;">We\'re excited to have you get started. First, you need to confirm your account.</p>\n                                    <p style="margin: 0;"> Below is your OTP code for verification. It expires in 5 minutes</p>\n                                </td>\n                            </tr>\n                            <tr>\n                                <td bgcolor="#ffffff" align="left">\n                                    <table width="100%" border="0" cellspacing="0" cellpadding="0">\n                                        <tr>\n                                            <td bgcolor="#ffffff" align="center" style="padding: 0px 60px 30px 30px;">\n                                                <table border="0" cellspacing="0" cellpadding="0">\n                                                    <tr>\n                                                        <h2>1234</h2>\n                                                    </tr>\n                                                </table>\n                                            </td>\n                                        </tr>\n                                    </table>\n                                </ ...

# %%
import datetime

# %%
#datetime.datetime.timestamp(datetime.timedelta(hours=1))
added = datetime.datetime.timestamp(datetime.timedelta(minutes=1) + datetime.datetime.now())

# %%
now = datetime.datetime.timestamp(datetime.datetime.now())
type(added - now)
# Out:
# float
